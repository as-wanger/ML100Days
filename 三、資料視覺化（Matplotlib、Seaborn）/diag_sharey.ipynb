# %%
import pandas as pd
a = pd.DataFrame({'A':[1,2,3,45],'B':[7,8,9,10]})
b = pd.DataFrame({'A':[1,4,7,51],'B':[9,3,10,7]})
A = pd.concat([a,b],axis=1,ignore_index=True)
display(A)
g = sns.PairGrid(A, diag_sharey=False)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot, colors="C0")
g.map_diag(sns.kdeplot, lw=2)
# Out:
#     0   1   2   3
# 0   1   7   1   9
# 1   2   8   4   3
# 2   3   9   7  10
# 3  45  10  51   7

# %%
g2 = sns.PairGrid(A, diag_sharey=True)
g2.map_upper(sns.scatterplot)
g2.map_lower(sns.kdeplot, colors="C0")
g2.map_diag(sns.kdeplot, lw=2)
